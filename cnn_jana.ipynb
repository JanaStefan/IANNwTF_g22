# %% [markdown]
# <a href="https://colab.research.google.com/github/JanaStefan/IANNwTF_g22/blob/main/cnn_jana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import keras
from keras import layers, losses, optimizers
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
from keras.datasets import cifar10

# %% [markdown]
# 1. Preparation and Inspection of the Data

# %%
def prep_cifar(train_data, test_data, batch_size, shuffle_buffer_size):
    def preprocessing_func(img, label):
        img = tf.cast(img, tf.float32)
        img = (img/128) - 1 #// normalized
        label = tf.one_hot(label, depth=10)
        return img, label
    train_data  = train_data.map(lambda img, label: preprocessing_func(img, label))
    train_data = train_data.shuffle(shuffle_buffer_size).batch(batch_size).prefetch(2)
    test_data = test_data.map(lambda img, label: preprocessing_func(img, label))
    test_data = test_data.batch(1)
    return train_data, test_data


def get_familiar_with_data(dataset, name):
    for images, labels in dataset.take(1):
        print(f"{name} batch size:", images.shape[0])
        print("Each image size:", images.shape[1:])
        sample_labels = labels.numpy()
        print(f"Sample labels from {name} set:", sample_labels[:5] if sample_labels.ndim > 0 else sample_labels)

def visualize_data(dataset):
    class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer',
                   'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

    plt.figure(figsize=(10, 10))
    for images, labels in dataset.take(1):
        num_images = min(images.shape[0], 25)

        for i in range(num_images):
            plt.subplot(5, 5, i + 1)
            plt.xticks([])
            plt.yticks([])
            plt.grid(False)
            plt.imshow(images[i], cmap=plt.cm.binary)
            plt.xlabel(class_names[labels[i].numpy()])

    plt.show()

# %%
train_data, test_data = tfds.load('cifar10', split=['train', 'test'], as_supervised=True)

# %%
get_familiar_with_data(train_data, 'cifar')
visualize_data(train_data)
# Out:
# cifar batch size: 32
# Each image size: (32, 3)
# Sample labels from cifar set: 7
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-30-869debe1a642> in <cell line: 2>()
#       1 get_familiar_with_data(train_data, 'cifar')
# ----> 2 visualize_data(train_data)
#
# <ipython-input-27-38b776bc3494> in visualize_data(dataset)
#      33             plt.grid(False)
#      34             plt.imshow(images[i], cmap=plt.cm.binary)
# ---> 35             plt.xlabel(class_names[labels[i].numpy()])
#      36
#      37     plt.show()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    5886 def raise_from_not_ok_status(e, name) -> NoReturn:
#    5887   e.message += (" name: " + str(name if name is not None else ""))
# -> 5888   raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    5889
#    5890
#
# InvalidArgumentError: {{function_node __wrapped__StridedSlice_device_/job:localhost/replica:0/task:0/device:GPU:0}} Attempting to slice scalar input. [Op:StridedSlice] name: strided_slice/

# %% [markdown]
# 2. The CNN Model

# %%
class CNN():
    def __init__(self, input_size=(32, 32, 3), num_filters=[32, 64, 128], kernel_size=[(3,3), (3,3), (3,3)], strides=[(1,1), (1,1), (1,1)], conv_activation='relu', cnn_pool_type="max_pool",
                 padding="valid", use_bias=False, dense_activation='relu', dense_sizes=[256], num_classes=10, flatten_type="global_max", name="CNN_model"):

        self.input_size = input_size
        self.num_filters = num_filters
        self.kernel_size = kernel_size
        self.strides = strides
        self.conv_activation = conv_activation
        self.cnn_pool_type = cnn_pool_type
        self.padding = padding
        self.use_bias = use_bias
        self.dense_activation = dense_activation
        self.dense_sizes = dense_sizes
        self.num_classes = num_classes
        self.flatten_type = flatten_type
        self.name = name
        self.last_performance = {
            'train_loss_results': [],
            'train_accuracy_results': [],
            'test_loss': -1,
            'test_accuracy': -1,
        }

        self.model = None
        self.create_cnn()



    def create_cnn(self):
        inputs = layers.Input(shape=(self.input_size), dtype=tf.float32)
        x = inputs

        # Create CNN part with pooling layers
        for i, num_filter in enumerate(self.num_filters):
            x = layers.Conv2D(num_filter, self.kernel_size[i], self.strides[i], self.padding, activation=self.conv_activation, use_bias=self.use_bias)(x)
            x = layers.BatchNormalization()(x)
            if self.cnn_pool_type == "max_pool":
                x = layers.MaxPool2D()(x)
            else:
                x = layers.AveragePooling2D()(x)
            #x = layers.Dropout(0.2)(x)

        # Flatten the output of the CNN part for it to fit into the MLP part
        if self.flatten_type == "global_max":
            x = layers.GlobalMaxPool2D()(x)
        else:
            x = layers.GlobalAveragePooling2D()(x)

        # Create the MLP part
        for i, dense_size in enumerate(self.dense_sizes):
            x = layers.Dense(dense_size, activation=self.dense_activation)(x)

        # Create the output part
        y = layers.Dense(units=self.num_classes, activation='softmax')(x)

        self.model = keras.Model(inputs=inputs, outputs=y, name=self.name)
        self.model.summary()




    def train(self, train_data, test_data, batch_size=64, shuffle_buffer_size=1000, epochs=15, learning_rate=0.01, optimizer='adam'):
        train_data, test_data = prep_cifar(train_data, test_data, batch_size, shuffle_buffer_size)

        if optimizer == 'adam':
          optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=learning_rate)
        else:
          optimizer = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)

        loss_f = tf.keras.losses.CategoricalCrossentropy()

        for epoch in range(epochs):
            epoch_loss_avg = tf.keras.metrics.Mean()
            epoch_accuracy = tf.keras.metrics.CategoricalAccuracy()
            for image, label in train_data:
                with tf.GradientTape() as tape:
                  pred = self.model(image)
                  loss = loss_f(label, pred)

                gradients = tape.gradient(loss, self.model.trainable_variables)
                optimizer.apply_gradients(zip(gradients, self.model.trainable_variables))

                epoch_loss_avg.update_state(loss)
                epoch_accuracy.update_state(label, pred)

            self.last_performance['train_loss_results'].append(epoch_loss_avg.result())
            self.last_performance['train_accuracy_results'].append(epoch_accuracy.result())
            print(f"Epoch {epoch+1}: Loss: {epoch_loss_avg.result()}, Accuracy: {epoch_accuracy.result()}")


        self.last_performance['test_loss'], self.last_performance['test_accuracy'] = self.evaluate(test_data)
        print(f"Test Loss: {self.last_performance['test_loss']}, Test Accuracy: {self.last_performance['test_accuracy']}")
        return self.last_performance['train_loss_results'], self.last_performance['train_accuracy_results'], self.last_performance['test_loss'], self.last_performance['test_accuracy']




    def evaluate(self, test_data):
      loss_f = tf.keras.losses.CategoricalCrossentropy()
      loss_list = []
      correct_predictions = 0
      for image, label in test_data:
          pred = self.model(image)
          loss = loss_f(label, pred)
          loss_list.append(loss)
          if np.argmax(label, axis=-1) == np.argmax(pred, axis=-1):
              correct_predictions += 1
      return np.average(loss_list), correct_predictions/len(test_data)




    def visualize_last_performance(self):
        # Plot training loss and accuracy
        epochs_range = range(len(self.last_performance['train_loss_results']))
        plt.figure(figsize=(12, 6))

        plt.subplot(1, 2, 1)
        plt.plot(epochs_range, self.last_performance['train_loss_results'], label='Training Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title('Training Loss')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(epochs_range, self.last_performance['train_accuracy_results'], label='Training Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.title('Training Accuracy')
        plt.legend()

        # Print and visualize test accuracy
        print(f"Test accuracy: {self.last_performance['test_accuracy']}")
        print(f"Test loss: {self.last_performance['test_loss']}")

        plt.show()

# %%
# Default Set of Hyperparameters for Testing Purposes

cnn_model = CNN()
performance_results = cnn_model.train(train_data, test_data, epochs=3)
cnn_model.visualize_last_performance()
# Out:
# Model: "CNN_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_24 (Conv2D)          (None, 30, 30, 32)        864
#
#  batch_normalization_24 (Ba  (None, 30, 30, 32)        128
#  tchNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 15, 15, 32)        0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 13, 13, 64)        18432
#
#  batch_normalization_25 (Ba  (None, 13, 13, 64)        256
#  tchNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 4, 4, 128)         73728
#
#  batch_normalization_26 (Ba  (None, 4, 4, 128)         512
#  tchNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  global_max_pooling2d_5 (Gl  (None, 128)               0
#  obalMaxPooling2D)
#
#  dense_10 (Dense)            (None, 256)               33024
#
#  dense_11 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 129514 (505.91 KB)
# Trainable params: 129066 (504.16 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# Epoch 1: Loss: 1.6489360332489014, Accuracy: 0.39566001296043396
# Epoch 2: Loss: 1.329201102256775, Accuracy: 0.5260800123214722
# Epoch 3: Loss: 1.1909797191619873, Accuracy: 0.5777599811553955
# Test Loss: 1.2115103006362915, Test Accuracy: 0.5847
# Test accuracy: 0.5847
# Test loss: 1.2115103006362915

# %% [markdown]
# 3. Hyperparameter Tuning

# %%
# Set 1:
set1_model = CNN(
    num_filters=[32, 64, 128],
    kernel_size=[(3,3), (3,3), (3,3)],
    strides=[(1,1), (1,1), (1,1)],
    conv_activation='elu',
    cnn_pool_type='max_pool',
    padding='valid',
    use_bias=False,
    dense_activation='softmax',
    dense_sizes=[128],
    flatten_type='global_max',
    name="Set_1",
)
train_data, test_data = tfds.load('cifar10', split=['train', 'test'], as_supervised=True)
set1_model.train(train_data, test_data, batch_size=32, shuffle_buffer_size=500, epochs=15, learning_rate=0.0001, optimizer='rmsprop')
set1_model.visualize_last_performance()
# Out:
# Model: "Set_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_27 (Conv2D)          (None, 30, 30, 32)        864
#
#  batch_normalization_27 (Ba  (None, 30, 30, 32)        128
#  tchNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 15, 15, 32)        0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 13, 13, 64)        18432
#
#  batch_normalization_28 (Ba  (None, 13, 13, 64)        256
#  tchNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 4, 4, 128)         73728
#
#  batch_normalization_29 (Ba  (None, 4, 4, 128)         512
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  global_max_pooling2d_6 (Gl  (None, 128)               0
#  obalMaxPooling2D)
#
#  dense_12 (Dense)            (None, 128)               16512
#
#  dense_13 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 111722 (436.41 KB)
# Trainable params: 111274 (434.66 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# Epoch 1: Loss: 2.2694857120513916, Accuracy: 0.17080000042915344
# WARNING:tensorflow:Gradients do not exist for variables ['conv2d_27/kernel:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['conv2d_27/kernel:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# Epoch 2: Loss: 2.195826768875122, Accuracy: 0.23955999314785004
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-22cd7c2fd363> in <cell line: 15>()
#      13     name="Set_1",
#      14 )
# ---> 15 set1_model.train(train_data, test_data, batch_size=32, shuffle_buffer_size=500, epochs=15, learning_rate=0.0001, optimizer='rmsprop')
#      16 set1_model.visualize_last_performance()
#
# <ipython-input-21-9050c1b68100> in train(self, train_data, test_data, batch_size, shuffle_buffer_size, epochs, learning_rate, optimizer)
#      76             for image, label in train_data:
#      77                 with tf.GradientTape() as tape:
# ---> 78                   pred = self.model(image)
#      79                   loss = loss_f(label, pred)
#      80
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in __call__(self, *args, **kwargs)
#     587             layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     588
# --> 589         return super().__call__(*args, **kwargs)
#     590
#     591     @doc_controls.doc_in_current_and_subclasses
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1147                     self._compute_dtype_object
#    1148                 ):
# -> 1149                     outputs = call_fn(inputs, *args, **kwargs)
#    1150
#    1151                 if self._activity_regularizer:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py in call(self, inputs, training, mask)
#     513             a list of tensors if there are more than one outputs.
#     514         """
# --> 515         return self._run_internal_graph(inputs, training=training, mask=mask)
#     516
#     517     def compute_output_shape(self, input_shape):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     670
#     671                 args, kwargs = node.map_arguments(tensor_dict)
# --> 672                 outputs = node.layer(*args, **kwargs)
#     673
#     674                 # Update tensor_dict.
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1147                     self._compute_dtype_object
#    1148                 ):
# -> 1149                     outputs = call_fn(inputs, *args, **kwargs)
#    1150
#    1151                 if self._activity_regularizer:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py in call(self, inputs)
#     239                 )
#     240             else:
# --> 241                 outputs = tf.matmul(a=inputs, b=self.kernel)
#     242         # Broadcast kernel to inputs.
#     243         else:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/math_ops.py in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, output_type, name)
#    3837             a, b, adj_x=adjoint_a, adj_y=adjoint_b, Tout=output_type, name=name)
#    3838       else:
# -> 3839         return gen_math_ops.mat_mul(
#    3840             a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#    3841
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_math_ops.py in mat_mul(a, b, transpose_a, transpose_b, name)
#    6168   if tld.is_eager:
#    6169     try:
# -> 6170       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6171         _ctx, "MatMul", name, a, b, "transpose_a", transpose_a, "transpose_b",
#    6172         transpose_b)
#
# KeyboardInterrupt:

# %% [markdown]
# Discussion of result:
# Slow learning due to low learning rate -> would need more epochs of training for a better performance

# %%
# Set 2:
set2_model = CNN(
    num_filters=[32, 64, 128],
    kernel_size=[(2,2), (3,3), (2,2)],
    strides=[(2,2), (1,1), (1,1)],
    conv_activation='elu',
    cnn_pool_type='max_pool',
    padding='valid',
    use_bias=False,
    dense_activation='softmax',
    dense_sizes=[128],
    flatten_type='global_max',
    name="Set_2",
)
train_data, test_data = tfds.load('cifar10', split=['train', 'test'], as_supervised=True)
set2_model.train(train_data, test_data, batch_size=32, shuffle_buffer_size=1000, epochs=15, learning_rate=0.01, optimizer='rmsprop')
set2_model.visualize_last_performance()
# Out:
# Model: "Set_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_30 (Conv2D)          (None, 16, 16, 32)        384
#
#  batch_normalization_30 (Ba  (None, 16, 16, 32)        128
#  tchNormalization)
#
#  max_pooling2d_9 (MaxPoolin  (None, 8, 8, 32)          0
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 6, 6, 64)          18432
#
#  batch_normalization_31 (Ba  (None, 6, 6, 64)          256
#  tchNormalization)
#
#  max_pooling2d_10 (MaxPooli  (None, 3, 3, 64)          0
#  ng2D)
#
#  conv2d_32 (Conv2D)          (None, 2, 2, 128)         32768
#
#  batch_normalization_32 (Ba  (None, 2, 2, 128)         512
#  tchNormalization)
#
#  max_pooling2d_11 (MaxPooli  (None, 1, 1, 128)         0
#  ng2D)
#
#  global_max_pooling2d_7 (Gl  (None, 128)               0
#  obalMaxPooling2D)
#
#  dense_14 (Dense)            (None, 128)               16512
#
#  dense_15 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 70282 (274.54 KB)
# Trainable params: 69834 (272.79 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# Epoch 1: Loss: 2.207639455795288, Accuracy: 0.15797999501228333
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-28491cf173be> in <cell line: 15>()
#      13     name="Set_2",
#      14 )
# ---> 15 set2_model.train(train_data, test_data, batch_size=32, shuffle_buffer_size=1000, epochs=15, learning_rate=0.01, optimizer='rmsprop')
#      16 set2_model.visualize_last_performance()
#
# <ipython-input-21-9050c1b68100> in train(self, train_data, test_data, batch_size, shuffle_buffer_size, epochs, learning_rate, optimizer)
#      77                 with tf.GradientTape() as tape:
#      78                   pred = self.model(image)
# ---> 79                   loss = loss_f(label, pred)
#      80
#      81                 gradients = tape.gradient(loss, self.model.trainable_variables)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/losses.py in __call__(self, y_true, y_pred, sample_weight)
#     143             losses = call_fn(y_true, y_pred)
#     144
# --> 145             in_mask = losses_utils.get_mask(y_pred)
#     146             out_mask = losses_utils.get_mask(losses)
#     147
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/losses_utils.py in get_mask(y_p)
#     398 def get_mask(y_p):
#     399     """Returns Keras mask from tensor."""
# --> 400     return getattr(y_p, "_keras_mask", None)
#     401
#     402
#
# KeyboardInterrupt:

# %%
# Set 3:
set3_model = CNN(
    num_filters=[64, 128, 128],
    kernel_size=[(2,2), (3,3), (2,2)],
    strides=[(2,2), (1,1), (1,1)],
    conv_activation='relu',
    cnn_pool_type='max_pool',
    padding='valid',
    use_bias=True,
    dense_activation='softmax',
    dense_sizes=[128],
    flatten_type='global_max',
    name="Set_3",
)
train_data, test_data = tfds.load('cifar10', split=['train', 'test'], as_supervised=True)
set3_model.train(train_data, test_data, batch_size=32, shuffle_buffer_size=1000, epochs=15, learning_rate=0.0001, optimizer='adam')
set3_model.visualize_last_performance()
# Out:
# Model: "Set_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_33 (Conv2D)          (None, 16, 16, 64)        832
#
#  batch_normalization_33 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  max_pooling2d_12 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  conv2d_34 (Conv2D)          (None, 6, 6, 128)         73856
#
#  batch_normalization_34 (Ba  (None, 6, 6, 128)         512
#  tchNormalization)
#
#  max_pooling2d_13 (MaxPooli  (None, 3, 3, 128)         0
#  ng2D)
#
#  conv2d_35 (Conv2D)          (None, 2, 2, 128)         65664
#
#  batch_normalization_35 (Ba  (None, 2, 2, 128)         512
#  tchNormalization)
#
#  max_pooling2d_14 (MaxPooli  (None, 1, 1, 128)         0
#  ng2D)
#
#  global_max_pooling2d_8 (Gl  (None, 128)               0
#  obalMaxPooling2D)
#
#  dense_16 (Dense)            (None, 128)               16512
#
#  dense_17 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 159434 (622.79 KB)
# Trainable params: 158794 (620.29 KB)
# Non-trainable params: 640 (2.50 KB)
# _________________________________________________________________
# Epoch 1: Loss: 2.2399685382843018, Accuracy: 0.1617400050163269
# Epoch 2: Loss: 2.170231580734253, Accuracy: 0.1920199990272522
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-8ca6509b5a49> in <cell line: 15>()
#      13     name="Set_3",
#      14 )
# ---> 15 set3_model.train(train_data, test_data, batch_size=32, shuffle_buffer_size=1000, epochs=15, learning_rate=0.0001, optimizer='adam')
#      16 set3_model.visualize_last_performance()
#
# <ipython-input-21-9050c1b68100> in train(self, train_data, test_data, batch_size, shuffle_buffer_size, epochs, learning_rate, optimizer)
#      77                 with tf.GradientTape() as tape:
#      78                   pred = self.model(image)
# ---> 79                   loss = loss_f(label, pred)
#      80
#      81                 gradients = tape.gradient(loss, self.model.trainable_variables)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/losses.py in __call__(self, y_true, y_pred, sample_weight)
#     159                 losses, sample_weight, mask, reduction
#     160             )
# --> 161             return losses_utils.compute_weighted_loss(
#     162                 losses, sample_weight, reduction=reduction
#     163             )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/losses_utils.py in compute_weighted_loss(losses, sample_weight, reduction, name)
#     352
#     353         # Apply reduction function to the individual weighted losses.
# --> 354         loss = reduce_weighted_loss(weighted_losses, reduction)
#     355         if input_casted:
#     356             # Convert the result back to the input type.
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/losses_utils.py in reduce_weighted_loss(weighted_losses, reduction)
#     283         loss = tf.reduce_sum(weighted_losses)
#     284         if reduction == ReductionV2.SUM_OVER_BATCH_SIZE:
# --> 285             loss = _safe_mean(loss, _num_elements(weighted_losses))
#     286     return loss
#     287
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/losses_utils.py in _safe_mean(losses, num_present)
#     264         then zero is returned.
#     265     """
# --> 266     total_loss = tf.reduce_sum(losses)
#     267     return tf.math.divide_no_nan(total_loss, num_present, name="value")
#     268
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/math_ops.py in reduce_sum(input_tensor, axis, keepdims, name)
#    2428
#    2429   return reduce_sum_with_dims(input_tensor, axis, keepdims, name,
# -> 2430                               _ReductionDims(input_tensor, axis))
#    2431
#    2432
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/math_ops.py in _ReductionDims(x, axis)
#    2268     else:
#    2269       # Otherwise, we rely on Range and Rank to do the right thing at run-time.
# -> 2270       return range(0, array_ops.rank(x))
#    2271
#    2272
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/math_ops.py in range(start, limit, delta, dtype, name)
#    2235     # tensors. This will resolve the case where start/limit/delta's original's
#    2236     # dtype is different from provided dtype.
# -> 2237     start = cast(start, inferred_dtype)
#    2238     limit = cast(limit, inferred_dtype)
#    2239     delta = cast(delta, inferred_dtype)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/math_ops.py in cast(x, dtype, name)
#     998   base_type = dtypes.as_dtype(dtype).base_dtype
#     999   if isinstance(
# -> 1000       x, (tensor_lib.Tensor, _resource_variable_type)) and base_type == x.dtype:
#    1001     return x
#    1002   with ops.name_scope(name, "Cast", [x]) as name:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/dtypes.py in __eq__(self, other)
#     258     return types_pb2.SerializedDType(datatype=self._type_enum)
#     259
# --> 260   def __eq__(self, other):
#     261     """Returns True iff this DType refers to the same type as `other`."""
#     262     if other is None:
#
# KeyboardInterrupt:

# %%
# Set 4:
set4_model = CNN(
    num_filters=[64, 128, 128],
    kernel_size=[(2,2), (3,3), (2,2)],
    strides=[(2,2), (1,1), (1,1)],
    conv_activation='relu',
    cnn_pool_type='max_pool',
    padding='valid',
    use_bias=True,
    dense_activation='softmax',
    dense_sizes=[128],
    flatten_type='global_max',
    name="Set_4",
)
train_data, test_data = tfds.load('cifar10', split=['train', 'test'], as_supervised=True)
set4_model.train(train_data, test_data, batch_size=64, shuffle_buffer_size=500, epochs=15, learning_rate=0.01, optimizer='rmsprop')
set4_model.visualize_last_performance()
# Out:
# Model: "Set_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_36 (Conv2D)          (None, 16, 16, 64)        832
#
#  batch_normalization_36 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  max_pooling2d_15 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  conv2d_37 (Conv2D)          (None, 6, 6, 128)         73856
#
#  batch_normalization_37 (Ba  (None, 6, 6, 128)         512
#  tchNormalization)
#
#  max_pooling2d_16 (MaxPooli  (None, 3, 3, 128)         0
#  ng2D)
#
#  conv2d_38 (Conv2D)          (None, 2, 2, 128)         65664
#
#  batch_normalization_38 (Ba  (None, 2, 2, 128)         512
#  tchNormalization)
#
#  max_pooling2d_17 (MaxPooli  (None, 1, 1, 128)         0
#  ng2D)
#
#  global_max_pooling2d_9 (Gl  (None, 128)               0
#  obalMaxPooling2D)
#
#  dense_18 (Dense)            (None, 128)               16512
#
#  dense_19 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 159434 (622.79 KB)
# Trainable params: 158794 (620.29 KB)
# Non-trainable params: 640 (2.50 KB)
# _________________________________________________________________
# Epoch 1: Loss: 2.2222235202789307, Accuracy: 0.15352000296115875
# Epoch 2: Loss: 2.1985764503479004, Accuracy: 0.15797999501228333
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-32-16174666d913> in <cell line: 15>()
#      14 )
# ---> 15 set4_model.train(train_data, test_data, batch_size=64, shuffle_buffer_size=500, epochs=15, learning_rate=0.01, optimizer='rmsprop')
#      16 set4_model.visualize_last_performance()
#
# <ipython-input-21-9050c1b68100> in train(self, train_data, test_data, batch_size, shuffle_buffer_size, epochs, learning_rate, optimizer)
#      78                   pred = self.model(image)
# ---> 79                   loss = loss_f(label, pred)
#      80
#
# /usr/local/lib/python3.10/dist-packages/keras/src/losses.py in __call__(self, y_true, y_pred, sample_weight)
#     142
# --> 143             losses = call_fn(y_true, y_pred)
#     144
#
# /usr/local/lib/python3.10/dist-packages/keras/src/losses.py in call(self, y_true, y_pred)
#     269         )
# --> 270         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     271
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/losses.py in categorical_crossentropy(y_true, y_pred, from_logits, label_smoothing, axis)
#    2220
# -> 2221     return backend.categorical_crossentropy(
#    2222         y_true, y_pred, from_logits=from_logits, axis=axis
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py in categorical_crossentropy(target, output, from_logits, axis)
#    5580     if from_logits:
# -> 5581         return tf.nn.softmax_cross_entropy_with_logits(
#    5582             labels=target, logits=output, axis=axis
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/nn_ops.py in softmax_cross_entropy_with_logits_v2(labels, logits, axis, name)
#    4044   """
# -> 4045   return softmax_cross_entropy_with_logits_v2_helper(
#    4046       labels=labels, logits=logits, axis=axis, name=name)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     587                 instructions)
# --> 588       return func(*args, **kwargs)
#     589
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/nn_ops.py in softmax_cross_entropy_with_logits_v2_helper(***failed resolving arguments***)
#    4140     # Make precise_logits and labels into matrices.
# -> 4141     precise_logits = _flatten_outer_dims(precise_logits)
#    4142     labels = _flatten_outer_dims(labels)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/nn_ops.py in _flatten_outer_dims(logits)
#    3757       array_ops.shape(logits), [math_ops.subtract(rank, 1)], [1])
# -> 3758   output = array_ops.reshape(logits, array_ops.concat([[-1], last_dim_size], 0))
#    3759
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/array_ops.py in concat(values, axis, name)
#    1696       return identity(values[0], name=name)
# -> 1697   return gen_array_ops.concat_v2(values=values, axis=axis, name=name)
#    1698
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_array_ops.py in concat_v2(values, axis, name)
#    1304     try:
# -> 1305       return concat_v2_eager_fallback(
#    1306           values, axis, name=name, ctx=_ctx)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_array_ops.py in concat_v2_eager_fallback(values, axis, name, ctx)
#    1335   _attr_N = len(values)
# -> 1336   _attr_T, values = _execute.args_to_matching_eager(list(values), ctx, [])
#    1337   _attr_Tidx, (axis,) = _execute.args_to_matching_eager([axis], ctx, [_dtypes.int32, _dtypes.int64, ], _dtypes.int32)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in args_to_matching_eager(***failed resolving arguments***)
#     273   else:
# --> 274     ret = [tensor_conversion_registry.convert(t, dtype) for t in l]
#     275
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in <listcomp>(.0)
#     273   else:
# --> 274     ret = [tensor_conversion_registry.convert(t, dtype) for t in l]
#     275
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     251               name=name))
# --> 252     if dtype and not dtype.is_compatible_with(ret.dtype):
#     253       raise RuntimeError(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in dtype(self)
#     365
# --> 366   @property
#     367   def dtype(self):
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
# Set 5:
set5_model = CNN(
    num_filters=[64, 64],
    kernel_size=[(3,3), (3,3)],
    strides=[(2,2), (2,2)],
    conv_activation='relu',
    cnn_pool_type='max_pool',
    padding='valid',
    use_bias=True,
    dense_activation='softmax',
    dense_sizes=[128],
    flatten_type='global_max',
    name="Set_5",
)
train_data, test_data = tfds.load('cifar10', split=['train', 'test'], as_supervised=True)
set5_model.train(train_data, test_data, batch_size=64, shuffle_buffer_size=500, epochs=15, learning_rate=0.01, optimizer='rmsprop')
set5_model.visualize_last_performance()
# Out:
# Model: "Set_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_39 (Conv2D)          (None, 15, 15, 64)        1792
#
#  batch_normalization_39 (Ba  (None, 15, 15, 64)        256
#  tchNormalization)
#
#  max_pooling2d_18 (MaxPooli  (None, 7, 7, 64)          0
#  ng2D)
#
#  conv2d_40 (Conv2D)          (None, 3, 3, 64)          36928
#
#  batch_normalization_40 (Ba  (None, 3, 3, 64)          256
#  tchNormalization)
#
#  max_pooling2d_19 (MaxPooli  (None, 1, 1, 64)          0
#  ng2D)
#
#  global_max_pooling2d_10 (G  (None, 64)                0
#  lobalMaxPooling2D)
#
#  dense_20 (Dense)            (None, 128)               8320
#
#  dense_21 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 48842 (190.79 KB)
# Trainable params: 48586 (189.79 KB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________
# Epoch 1: Loss: 2.0293779373168945, Accuracy: 0.23183999955654144
# Epoch 2: Loss: 1.9631550312042236, Accuracy: 0.2692199945449829
# Epoch 3: Loss: 1.9711394309997559, Accuracy: 0.2684600055217743
# Epoch 4: Loss: 1.9840304851531982, Accuracy: 0.2543399930000305
# Epoch 5: Loss: 2.022665500640869, Accuracy: 0.2310599982738495
# Epoch 6: Loss: 2.049173355102539, Accuracy: 0.2113800048828125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-c19b5fd161e6> in <cell line: 16>()
#      14 )
#      15 train_data, test_data = tfds.load('cifar10', split=['train', 'test'], as_supervised=True)
# ---> 16 set5_model.train(train_data, test_data, batch_size=64, shuffle_buffer_size=500, epochs=15, learning_rate=0.01, optimizer='rmsprop')
#      17 set5_model.visualize_last_performance()
#
# <ipython-input-21-9050c1b68100> in train(self, train_data, test_data, batch_size, shuffle_buffer_size, epochs, learning_rate, optimizer)
#      80
#      81                 gradients = tape.gradient(loss, self.model.trainable_variables)
# ---> 82                 optimizer.apply_gradients(zip(gradients, self.model.trainable_variables))
#      83
#      84                 epoch_loss_avg.update_state(loss)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py in apply_gradients(self, grads_and_vars, name, skip_gradients_aggregation, **kwargs)
#    1221         if not skip_gradients_aggregation and experimental_aggregate_gradients:
#    1222             grads_and_vars = self.aggregate_gradients(grads_and_vars)
# -> 1223         return super().apply_gradients(grads_and_vars, name=name)
#    1224
#    1225     def _apply_weight_decay(self, variables):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py in apply_gradients(self, grads_and_vars, name)
#     650             self._apply_weight_decay(trainable_variables)
#     651             grads_and_vars = list(zip(grads, trainable_variables))
# --> 652             iteration = self._internal_apply_gradients(grads_and_vars)
#     653
#     654             # Apply variable constraints after applying gradients.
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py in _internal_apply_gradients(self, grads_and_vars)
#    1251             return super()._internal_apply_gradients(grads_and_vars)
#    1252
# -> 1253         return tf.__internal__.distribute.interim.maybe_merge_call(
#    1254             self._distributed_apply_gradients_fn,
#    1255             self._distribution_strategy,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/merge_call_interim.py in maybe_merge_call(fn, strategy, *args, **kwargs)
#      49   """
#      50   if strategy_supports_no_merge_call():
# ---> 51     return fn(strategy, *args, **kwargs)
#      52   else:
#      53     return distribute_lib.get_replica_context().merge_call(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py in _distributed_apply_gradients_fn(self, distribution, grads_and_vars, **kwargs)
#    1343
#    1344         for grad, var in grads_and_vars:
# -> 1345             distribution.extended.update(
#    1346                 var, apply_grad_to_update_var, args=(grad,), group=False
#    1347             )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in update(self, var, fn, args, kwargs, group)
#    3009           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    3010       with self._container_strategy().scope():
# -> 3011         return self._update(var, fn, args, kwargs, group)
#    3012     else:
#    3013       return self._replica_ctx_update(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in _update(self, var, fn, args, kwargs, group)
#    4079     # The implementations of _update() and _update_non_slot() are identical
#    4080     # except _update() passes `var` as the first argument to `fn()`.
# -> 4081     return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#    4082
#    4083   def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in _update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4085     # once that value is used for something.
#    4086     with UpdateContext(colocate_with):
# -> 4087       result = fn(*args, **kwargs)
#    4088       if should_group:
#    4089         return result
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     594   def wrapper(*args, **kwargs):
#     595     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 596       return func(*args, **kwargs)
#     597
#     598   if inspect.isfunction(func) or inspect.ismethod(func):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py in apply_grad_to_update_var(var, grad)
#    1338         def apply_grad_to_update_var(var, grad):
#    1339             if self.jit_compile:
# -> 1340                 return self._update_step_xla(grad, var, id(self._var_key(var)))
#    1341             else:
#    1342                 return self._update_step(grad, var)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     829
#     830       with OptionalXlaContext(self._jit_compile):
# --> 831         result = self._call(*args, **kwds)
#     832
#     833       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     874       # In this case we have not created variables on the first call. So we can
#     875       # run the first trace but we should fail if variables are created.
# --> 876       results = tracing_compilation.call_function(
#     877           args, kwds, self._variable_creation_config
#     878       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     130   args = args if args else ()
#     131   kwargs = kwargs if kwargs else {}
# --> 132   function = trace_function(
#     133       args=args, kwargs=kwargs, tracing_options=tracing_options
#     134   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     229   )
#     230   lookup_func_type, lookup_func_context = (
# --> 231       function_type_utils.make_canonicalized_monomorphic_type(
#     232           args,
#     233           kwargs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/function_type_utils.py in make_canonicalized_monomorphic_type(args, kwargs, capture_types, polymorphic_type)
#     368
#     369   function_type, type_context = (
# --> 370       function_type_lib.canonicalize_to_monomorphic(
#     371           args, kwargs, {}, capture_types, polymorphic_type
#     372       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/core/function/polymorphism/function_type.py in canonicalize_to_monomorphic(args, kwargs, default_values, capture_types, polymorphic_type)
#     555     else:
#     556       parameters.append(
# --> 557           _make_validated_mono_param(name, arg, poly_parameter.kind,
#     558                                      type_context,
#     559                                      poly_parameter.type_constraint))
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/core/function/polymorphism/function_type.py in _make_validated_mono_param(name, value, kind, type_context, poly_type)
#     500                     f"{poly_type} but is {mono_type}")
#     501
# --> 502   return Parameter(name, kind, False, mono_type)
#     503
#     504
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/core/function/polymorphism/function_type.py in __init__(self, name, kind, optional, type_constraint)
#      69           "type_constraint=" + str(type_constraint) + " for Parameter " + name)
#      70
# ---> 71     super().__init__(
#      72         name,
#      73         kind,
#
# /usr/lib/python3.10/inspect.py in __init__(self, name, kind, default, annotation)
#    2637     def __init__(self, name, kind, *, default=_empty, annotation=_empty):
#    2638         try:
# -> 2639             self._kind = _ParameterKind(kind)
#    2640         except ValueError:
#    2641             raise ValueError(f'value {kind!r} is not a valid Parameter.kind')
#
# /usr/lib/python3.10/enum.py in __call__(cls, value, names, module, qualname, type, start)
#     383         """
#     384         if names is None:  # simple value lookup
# --> 385             return cls.__new__(cls, value)
#     386         # otherwise, functional API: we're creating a new Enum type
#     387         return cls._create_(
#
# /usr/lib/python3.10/enum.py in __new__(cls, value)
#     676     Derive from this class to define new enumerations.
#     677     """
# --> 678     def __new__(cls, value):
#     679         # all enum instances are actually created during class construction
#     680         # without calling this method; this method is called by the metaclass'
#
# KeyboardInterrupt:

# %%
# Set 6:
set6_model = CNN(
    num_filters=[64, 128],
    kernel_size=[(3,3), (3,3)],
    strides=[(2,2), (2,2)],
    conv_activation='relu',
    cnn_pool_type='av_pool',
    padding='valid',
    use_bias=True,
    dense_activation='softmax',
    dense_sizes=[128],
    flatten_type='av_max',
    name="Set_6",
)
train_data, test_data = tfds.load('cifar10', split=['train', 'test'], as_supervised=True)
set6_model.train(train_data, test_data, batch_size=64, shuffle_buffer_size=500, epochs=15, learning_rate=0.01, optimizer='rmsprop')
set6_model.visualize_last_performance()
# Out:
# Model: "Set_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_41 (Conv2D)          (None, 15, 15, 64)        1792
#
#  batch_normalization_41 (Ba  (None, 15, 15, 64)        256
#  tchNormalization)
#
#  average_pooling2d_21 (Aver  (None, 7, 7, 64)          0
#  agePooling2D)
#
#  conv2d_42 (Conv2D)          (None, 3, 3, 128)         73856
#
#  batch_normalization_42 (Ba  (None, 3, 3, 128)         512
#  tchNormalization)
#
#  average_pooling2d_22 (Aver  (None, 1, 1, 128)         0
#  agePooling2D)
#
#  global_average_pooling2d (  (None, 128)               0
#  GlobalAveragePooling2D)
#
#  dense_22 (Dense)            (None, 128)               16512
#
#  dense_23 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 94218 (368.04 KB)
# Trainable params: 93834 (366.54 KB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# Epoch 1: Loss: 2.020244836807251, Accuracy: 0.24087999761104584
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-7bc5c52b6d7b> in <cell line: 16>()
#      14 )
#      15 train_data, test_data = tfds.load('cifar10', split=['train', 'test'], as_supervised=True)
# ---> 16 set6_model.train(train_data, test_data, batch_size=64, shuffle_buffer_size=500, epochs=15, learning_rate=0.01, optimizer='rmsprop')
#      17 set6_model.visualize_last_performance()
#
# <ipython-input-21-9050c1b68100> in train(self, train_data, test_data, batch_size, shuffle_buffer_size, epochs, learning_rate, optimizer)
#      82                 optimizer.apply_gradients(zip(gradients, self.model.trainable_variables))
#      83
# ---> 84                 epoch_loss_avg.update_state(loss)
#      85                 epoch_accuracy.update_state(label, pred)
#      86
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/metrics_utils.py in decorated(metric_obj, *args, **kwargs)
#      75
#      76         with tf_utils.graph_context_for_symbolic_tensors(*args, **kwargs):
# ---> 77             result = update_state_fn(*args, **kwargs)
#      78         if not tf.executing_eagerly():
#      79             result = tf.compat.v1.get_default_graph().get_operations()[-1]
#
# /usr/local/lib/python3.10/dist-packages/keras/src/metrics/base_metric.py in update_state_fn(*args, **kwargs)
#     138                     obj_update_state, control_status
#     139                 )
# --> 140                 return ag_update_state(*args, **kwargs)
#     141
#     142         else:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     688       try:
#     689         with conversion_ctx:
# --> 690           return converted_call(f, args, kwargs, options=options)
#     691       except Exception as e:  # pylint:disable=broad-except
#     692         if hasattr(e, 'ag_error_metadata'):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     319       arguments.
#     320   """
# --> 321   logging.log(1, 'Converted call: %s\n    args: %s\n    kwargs: %s\n', f, args,
#     322               kwargs)
#     323
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/utils/ag_logging.py in log(level, msg, *args, **kwargs)
#     133
#     134 def log(level, msg, *args, **kwargs):
# --> 135   if has_verbosity(level):
#     136     logging.info(msg, *args, **kwargs)
#     137     if echo_log_to_stdout:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/utils/ag_logging.py in has_verbosity(level)
#     116
#     117 def has_verbosity(level):
# --> 118   return get_verbosity() >= level
#     119
#     120
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/utils/ag_logging.py in get_verbosity()
#     112   if verbosity_level is not None:
#     113     return verbosity_level
# --> 114   return int(os.getenv(VERBOSITY_VAR_NAME, DEFAULT_VERBOSITY))
#     115
#     116
#
# /usr/lib/python3.10/os.py in getenv(key, default)
#     774     The optional second argument can specify an alternate default.
#     775     key, default and the result are str."""
# --> 776     return environ.get(key, default)
#     777
#     778 supports_bytes_environ = (name != 'nt')
#
# /usr/lib/python3.10/_collections_abc.py in get(self, key, default)
#     822         'D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.'
#     823         try:
# --> 824             return self[key]
#     825         except KeyError:
#     826             return default
#
# /usr/lib/python3.10/os.py in __getitem__(self, key)
#     675     def __getitem__(self, key):
#     676         try:
# --> 677             value = self._data[self.encodekey(key)]
#     678         except KeyError:
#     679             # raise KeyError with the original key value
#
# /usr/lib/python3.10/os.py in encode(value)
#     756             if not isinstance(value, str):
#     757                 raise TypeError("str expected, not %s" % type(value).__name__)
# --> 758             return value.encode(encoding, 'surrogateescape')
#     759         def decode(value):
#     760             return value.decode(encoding, 'surrogateescape')
#
# KeyboardInterrupt:

# %%
# Set 7:
set7_model = CNN(
    num_filters=[64, 128],
    kernel_size=[(3,3), (3,3)],
    strides=[(1,1), (1,1)],
    conv_activation='relu',
    cnn_pool_type='av_pool',
    padding='valid',
    use_bias=False,
    dense_activation='tanh',
    dense_sizes=[128],
    flatten_type='av_max',
    name="Set_7",
)
train_data, test_data = tfds.load('cifar10', split=['train', 'test'], as_supervised=True)
set7_model.train(train_data, test_data, batch_size=32, shuffle_buffer_size=1000, epochs=15, learning_rate=0.01, optimizer='rmsprop')
set7_model.visualize_last_performance()
# Out:
# Model: "Set_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_43 (Conv2D)          (None, 30, 30, 64)        1728
#
#  batch_normalization_43 (Ba  (None, 30, 30, 64)        256
#  tchNormalization)
#
#  average_pooling2d_23 (Aver  (None, 15, 15, 64)        0
#  agePooling2D)
#
#  conv2d_44 (Conv2D)          (None, 13, 13, 128)       73728
#
#  batch_normalization_44 (Ba  (None, 13, 13, 128)       512
#  tchNormalization)
#
#  average_pooling2d_24 (Aver  (None, 6, 6, 128)         0
#  agePooling2D)
#
#  global_average_pooling2d_1  (None, 128)               0
#   (GlobalAveragePooling2D)
#
#  dense_24 (Dense)            (None, 128)               16512
#
#  dense_25 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 94026 (367.29 KB)
# Trainable params: 93642 (365.79 KB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# Epoch 1: Loss: 1.7323663234710693, Accuracy: 0.35242000222206116
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-9ba59850b603> in <cell line: 16>()
#      14 )
#      15 train_data, test_data = tfds.load('cifar10', split=['train', 'test'], as_supervised=True)
# ---> 16 set7_model.train(train_data, test_data, batch_size=32, shuffle_buffer_size=1000, epochs=15, learning_rate=0.01, optimizer='rmsprop')
#      17 set7_model.visualize_last_performance()
#
# <ipython-input-21-9050c1b68100> in train(self, train_data, test_data, batch_size, shuffle_buffer_size, epochs, learning_rate, optimizer)
#      80
#      81                 gradients = tape.gradient(loss, self.model.trainable_variables)
# ---> 82                 optimizer.apply_gradients(zip(gradients, self.model.trainable_variables))
#      83
#      84                 epoch_loss_avg.update_state(loss)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py in apply_gradients(self, grads_and_vars, name, skip_gradients_aggregation, **kwargs)
#    1221         if not skip_gradients_aggregation and experimental_aggregate_gradients:
#    1222             grads_and_vars = self.aggregate_gradients(grads_and_vars)
# -> 1223         return super().apply_gradients(grads_and_vars, name=name)
#    1224
#    1225     def _apply_weight_decay(self, variables):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py in apply_gradients(self, grads_and_vars, name)
#     650             self._apply_weight_decay(trainable_variables)
#     651             grads_and_vars = list(zip(grads, trainable_variables))
# --> 652             iteration = self._internal_apply_gradients(grads_and_vars)
#     653
#     654             # Apply variable constraints after applying gradients.
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py in _internal_apply_gradients(self, grads_and_vars)
#    1251             return super()._internal_apply_gradients(grads_and_vars)
#    1252
# -> 1253         return tf.__internal__.distribute.interim.maybe_merge_call(
#    1254             self._distributed_apply_gradients_fn,
#    1255             self._distribution_strategy,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/merge_call_interim.py in maybe_merge_call(fn, strategy, *args, **kwargs)
#      49   """
#      50   if strategy_supports_no_merge_call():
# ---> 51     return fn(strategy, *args, **kwargs)
#      52   else:
#      53     return distribute_lib.get_replica_context().merge_call(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py in _distributed_apply_gradients_fn(self, distribution, grads_and_vars, **kwargs)
#    1343
#    1344         for grad, var in grads_and_vars:
# -> 1345             distribution.extended.update(
#    1346                 var, apply_grad_to_update_var, args=(grad,), group=False
#    1347             )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in update(self, var, fn, args, kwargs, group)
#    3009           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    3010       with self._container_strategy().scope():
# -> 3011         return self._update(var, fn, args, kwargs, group)
#    3012     else:
#    3013       return self._replica_ctx_update(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in _update(self, var, fn, args, kwargs, group)
#    4079     # The implementations of _update() and _update_non_slot() are identical
#    4080     # except _update() passes `var` as the first argument to `fn()`.
# -> 4081     return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#    4082
#    4083   def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in _update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4085     # once that value is used for something.
#    4086     with UpdateContext(colocate_with):
# -> 4087       result = fn(*args, **kwargs)
#    4088       if should_group:
#    4089         return result
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     594   def wrapper(*args, **kwargs):
#     595     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 596       return func(*args, **kwargs)
#     597
#     598   if inspect.isfunction(func) or inspect.ismethod(func):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/optimizer.py in apply_grad_to_update_var(var, grad)
#    1338         def apply_grad_to_update_var(var, grad):
#    1339             if self.jit_compile:
# -> 1340                 return self._update_step_xla(grad, var, id(self._var_key(var)))
#    1341             else:
#    1342                 return self._update_step(grad, var)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     829
#     830       with OptionalXlaContext(self._jit_compile):
# --> 831         result = self._call(*args, **kwds)
#     832
#     833       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     874       # In this case we have not created variables on the first call. So we can
#     875       # run the first trace but we should fail if variables are created.
# --> 876       results = tracing_compilation.call_function(
#     877           args, kwds, self._variable_creation_config
#     878       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     130   args = args if args else ()
#     131   kwargs = kwargs if kwargs else {}
# --> 132   function = trace_function(
#     133       args=args, kwargs=kwargs, tracing_options=tracing_options
#     134   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     229   )
#     230   lookup_func_type, lookup_func_context = (
# --> 231       function_type_utils.make_canonicalized_monomorphic_type(
#     232           args,
#     233           kwargs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/function_type_utils.py in make_canonicalized_monomorphic_type(args, kwargs, capture_types, polymorphic_type)
#     368
#     369   function_type, type_context = (
# --> 370       function_type_lib.canonicalize_to_monomorphic(
#     371           args, kwargs, {}, capture_types, polymorphic_type
#     372       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/core/function/polymorphism/function_type.py in canonicalize_to_monomorphic(args, kwargs, default_values, capture_types, polymorphic_type)
#     555     else:
#     556       parameters.append(
# --> 557           _make_validated_mono_param(name, arg, poly_parameter.kind,
#     558                                      type_context,
#     559                                      poly_parameter.type_constraint))
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/core/function/polymorphism/function_type.py in _make_validated_mono_param(name, value, kind, type_context, poly_type)
#     494 ) -> Parameter:
#     495   """Generates and validates a parameter for Monomorphic FunctionType."""
# --> 496   mono_type = trace_type.from_value(value, type_context)
#     497
#     498   if poly_type and not mono_type.is_subtype_of(poly_type):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/core/function/trace_type/trace_type_builder.py in from_value(value, context)
#     140   if context.is_legacy_signature and isinstance(value, trace.TraceType):
#     141     return value
# --> 142   elif isinstance(value, trace.SupportsTracingProtocol):
#     143     generated_type = value.__tf_tracing_type__(context)
#     144     if not isinstance(generated_type, trace.TraceType):
#
# /usr/lib/python3.10/typing.py in __instancecheck__(cls, instance)
#    1500
#    1501         if ((not getattr(cls, '_is_protocol', False) or
# -> 1502                 _is_callable_members_only(cls)) and
#    1503                 issubclass(instance.__class__, cls)):
#    1504             return True
#
# /usr/lib/python3.10/typing.py in _is_callable_members_only(cls)
#    1425 def _is_callable_members_only(cls):
#    1426     # PEP 544 prohibits using issubclass() with protocols that have non-method members.
# -> 1427     return all(callable(getattr(cls, attr, None)) for attr in _get_protocol_attrs(cls))
#    1428
#    1429
#
# /usr/lib/python3.10/typing.py in _get_protocol_attrs(cls)
#    1418         annotations = getattr(base, '__annotations__', {})
#    1419         for attr in list(base.__dict__.keys()) + list(annotations.keys()):
# -> 1420             if not attr.startswith('_abc_') and attr not in EXCLUDED_ATTRIBUTES:
#    1421                 attrs.add(attr)
#    1422     return attrs
#
# KeyboardInterrupt:

# %%
# Set 8:
set8_model = CNN(
    num_filters=[32, 64, 128, 128],
    kernel_size=[(2,2), (2,2), (2,2), (2,2)],
    strides=[(1,1), (1,1), (1,1), (1,1)],
    conv_activation='elu',
    cnn_pool_type= 'max_pool',
    padding='valid',
    use_bias=False,
    dense_activation='softmax',
    dense_sizes=[128],
    flatten_type='global_max',
    name="Set_8",
)
train_data, test_data = tfds.load('cifar10', split=['train', 'test'], as_supervised=True)
set8_model.train(train_data, test_data, batch_size=32, shuffle_buffer_size=1000, epochs=15, learning_rate=0.01, optimizer='rmsprop')
set8_model.visualize_last_performance()
# Out:
# Model: "Set_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_52 (Conv2D)          (None, 31, 31, 32)        384
#
#  batch_normalization_52 (Ba  (None, 31, 31, 32)        128
#  tchNormalization)
#
#  max_pooling2d_27 (MaxPooli  (None, 15, 15, 32)        0
#  ng2D)
#
#  conv2d_53 (Conv2D)          (None, 14, 14, 64)        8192
#
#  batch_normalization_53 (Ba  (None, 14, 14, 64)        256
#  tchNormalization)
#
#  max_pooling2d_28 (MaxPooli  (None, 7, 7, 64)          0
#  ng2D)
#
#  conv2d_54 (Conv2D)          (None, 6, 6, 128)         32768
#
#  batch_normalization_54 (Ba  (None, 6, 6, 128)         512
#  tchNormalization)
#
#  max_pooling2d_29 (MaxPooli  (None, 3, 3, 128)         0
#  ng2D)
#
#  conv2d_55 (Conv2D)          (None, 2, 2, 128)         65536
#
#  batch_normalization_55 (Ba  (None, 2, 2, 128)         512
#  tchNormalization)
#
#  max_pooling2d_30 (MaxPooli  (None, 1, 1, 128)         0
#  ng2D)
#
#  global_max_pooling2d_11 (G  (None, 128)               0
#  lobalMaxPooling2D)
#
#  dense_26 (Dense)            (None, 128)               16512
#
#  dense_27 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 126090 (492.54 KB)
# Trainable params: 125386 (489.79 KB)
# Non-trainable params: 704 (2.75 KB)
# _________________________________________________________________
# Epoch 1: Loss: 2.297894239425659, Accuracy: 0.10657999664545059
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-d6db55ed25dc> in <cell line: 16>()
#      14 )
#      15 train_data, test_data = tfds.load('cifar10', split=['train', 'test'], as_supervised=True)
# ---> 16 set8_model.train(train_data, test_data, batch_size=32, shuffle_buffer_size=1000, epochs=15, learning_rate=0.01, optimizer='rmsprop')
#      17 set8_model.visualize_last_performance()
#
# <ipython-input-21-9050c1b68100> in train(self, train_data, test_data, batch_size, shuffle_buffer_size, epochs, learning_rate, optimizer)
#      77                 with tf.GradientTape() as tape:
#      78                   pred = self.model(image)
# ---> 79                   loss = loss_f(label, pred)
#      80
#      81                 gradients = tape.gradient(loss, self.model.trainable_variables)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/losses.py in __call__(self, y_true, y_pred, sample_weight)
#     141                 )
#     142
# --> 143             losses = call_fn(y_true, y_pred)
#     144
#     145             in_mask = losses_utils.get_mask(y_pred)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/losses.py in call(self, y_true, y_pred)
#     268             self.fn, tf.__internal__.autograph.control_status_ctx()
#     269         )
# --> 270         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     271
#     272     def get_config(self):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/keras/src/losses.py in categorical_crossentropy(y_true, y_pred, from_logits, label_smoothing, axis)
#    2219     )
#    2220
# -> 2221     return backend.categorical_crossentropy(
#    2222         y_true, y_pred, from_logits=from_logits, axis=axis
#    2223     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py in categorical_crossentropy(target, output, from_logits, axis)
#    5579     )
#    5580     if from_logits:
# -> 5581         return tf.nn.softmax_cross_entropy_with_logits(
#    5582             labels=target, logits=output, axis=axis
#    5583         )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/nn_ops.py in softmax_cross_entropy_with_logits_v2(labels, logits, axis, name)
#    4043     not have the last dimension of `labels`.
#    4044   """
# -> 4045   return softmax_cross_entropy_with_logits_v2_helper(
#    4046       labels=labels, logits=logits, axis=axis, name=name)
#    4047
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     586                 'in a future version' if date is None else ('after %s' % date),
#     587                 instructions)
# --> 588       return func(*args, **kwargs)
#     589
#     590     doc = _add_deprecated_arg_notice_to_docstring(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/nn_ops.py in softmax_cross_entropy_with_logits_v2_helper(***failed resolving arguments***)
#    4140     # Make precise_logits and labels into matrices.
#    4141     precise_logits = _flatten_outer_dims(precise_logits)
# -> 4142     labels = _flatten_outer_dims(labels)
#    4143
#    4144     # Do the actual op computation.
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/nn_ops.py in _flatten_outer_dims(logits)
#    3755   rank = array_ops.rank(logits)
#    3756   last_dim_size = array_ops.slice(
# -> 3757       array_ops.shape(logits), [math_ops.subtract(rank, 1)], [1])
#    3758   output = array_ops.reshape(logits, array_ops.concat([[-1], last_dim_size], 0))
#    3759
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/array_ops.py in shape(input, name, out_type)
#     695     else:
#     696       out_type = dtypes.int32
# --> 697   return shape_internal(input, name, optimize=True, out_type=out_type)
#     698
#     699
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/array_ops.py in shape_internal(input, name, optimize, out_type)
#     736       if not out_type:
#     737         out_type = dtypes.int32
# --> 738       return gen_array_ops.shape(input, name=name, out_type=out_type)
#     739
#     740
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_array_ops.py in shape(input, out_type, name)
#    9580   if tld.is_eager:
#    9581     try:
# -> 9582       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    9583         _ctx, "Shape", name, input, "out_type", out_type)
#    9584       return _result
#
# KeyboardInterrupt:
